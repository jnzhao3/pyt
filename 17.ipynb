# %% [markdown]
# # 17 Transposing

# %% [markdown]
# ## 2D Transpose

# %%
import numpy as np

# %%
x = np.array([[1, 2, 3],
              [4, 5, 6]])
x.T # (2, 3) -> (3, 2)
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
x.strides
# Out:
# (24, 8)

# %%
x.shape
# Out:
# (2, 3)

# %%
x.transpose(1, 0)
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
x.swapaxes(0, 1)
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
